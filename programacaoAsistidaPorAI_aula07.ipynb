# %% [markdown]
# <a href="https://colab.research.google.com/github/matheusgg18/engenharia-de-prompt-fundamentos/blob/main/programacaoAsistidaPorAI_aula07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Aula 07_miniprojeto
# Nome: Matheus Teixeira de Oliveira

# %%
print('devagar painho')
# Out:
# devagar painho
